# %% [markdown]
# <a href="https://colab.research.google.com/github/240609/MLF/blob/main/FeedforwardNN/FeedforwardNN_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 1, 1, 0])

model = Sequential()
model.add(InputLayer(input_shape=(2,)))
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.SGD(learning_rate=0.8)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
history = model.fit(X, y, epochs=1500, batch_size=3, verbose=0)

loss, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 100.00

# %%
for id_x, data_sample in enumerate(X):
  data_sample = np.array(data_sample.reshape(1, -1))
  prediction = model.predict(data_sample)
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")

plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Data sample is [[0 0]], prediction from model [[0.01065103]], ground_truth 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Data sample is [[0 1]], prediction from model [[0.9919941]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Data sample is [[1 0]], prediction from model [[0.9920023]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Data sample is [[1 1]], prediction from model [[0.01281461]], ground_truth 0
# Text(0, 0.5, 'loss')
